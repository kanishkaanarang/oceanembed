# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       2 import numpy as np
#       3
# ----> 4 df_full = ds_2026[['PLATFORM_NUMBER','CYCLE_NUMBER','LATITUDE','LONGITUDE','TIME','PRES','TEMP']].to_dataframe().reset_index()
#       5 df_full = df_full.dropna(subset=['TEMP', 'PRES'])
#       6
#       7 rows = []
#
# NameError: name 'ds_2026' is not defined
